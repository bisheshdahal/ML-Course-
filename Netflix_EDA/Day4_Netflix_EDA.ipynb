# %%
import numpy as np
import pandas as pd

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
netflix = pd.read_csv(r"netflix_data.csv")

# %%
netflix.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
netflix[netflix["title"] == "Shutter Island"]
# Out:
#      show_id   type           title         director  \
# 1358   s1359  Movie  Shutter Island  Martin Scorsese
#
#                                                    cast        country  \
# 1358  Leonardo DiCaprio, Mark Ruffalo, Ben Kingsley,...  United States
#
#             date_added  release_year rating duration  listed_in  \
# 1358  February 1, 2021          2010      R  139 min  Thrillers
#
#                                             description
# 1358  A U.S. marshal's troubling visions compromise ...

# %%
netflix[netflix["title"] == "Shutter Island"]["description"]
# Out:
# 1358    A U.S. marshal's troubling visions compromise ...
# Name: description, dtype: str

# %%
netflix[netflix["title"] == "Shutter Island"]["description"][1358]
# Out:
# "A U.S. marshal's troubling visions compromise his investigation into the disappearance of a patient from a hospital for the criminally insane."

# %%
netflix[netflix["title"] == "Better Call Saul"]["description"][2931]
# Out:
# 'This Emmy-nominated prequel to "Breaking Bad" follows small-time attorney Jimmy McGill as he transforms into morally challenged lawyer Saul Goodman.'

# %%
netflix.shape
# Out:
# (8807, 12)

# %% [markdown]
# Name Of Columns

# %%
netflix.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='str')

# %%
#CHeck NUll Value

netflix.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
#Check UNique values

netflix.nunique()
# Out:
# show_id         8807
# type               2
# title           8807
# director        4528
# cast            7692
# country          748
# date_added      1714
# release_year      74
# rating            17
# duration         220
# listed_in        514
# description     8775
# dtype: int64

# %%
netflix['type'].unique()
# Out:
# <StringArray>
# ['Movie', 'TV Show']
# Length: 2, dtype: str

# %%
netflix.duplicated().sum()
# Out:
# np.int64(0)

# %%
#make a ccopy of the dataset

df = netflix.copy()

# %%
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
df = df.dropna()

# %%
df.isnull().sum()
# Out:
# show_id         0
# type            0
# title           0
# director        0
# cast            0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# description     0
# dtype: int64

# %%
df.dtypes
# Out:
# show_id           str
# type              str
# title             str
# director          str
# cast              str
# country           str
# date_added        str
# release_year    int64
# rating            str
# duration          str
# listed_in         str
# description       str
# dtype: object

# %%
'        hello      '.strip()
# Out:
# 'hello'

# %%
df["date_added"] #month, day, year
# Out:
# 7       September 24, 2021
# 8       September 24, 2021
# 9       September 24, 2021
# 12      September 23, 2021
# 24      September 21, 2021
#                ...
# 8801         March 9, 2016
# 8802     November 20, 2019
# 8804      November 1, 2019
# 8805      January 11, 2020
# 8806         March 2, 2019
# Name: date_added, Length: 5332, dtype: str

# %%
df = netflix.copy()
df = df.dropna()
df["date_added"] = df["date_added"].str.strip()
df["date_added"]
# Out:
# 7       September 24, 2021
# 8       September 24, 2021
# 9       September 24, 2021
# 12      September 23, 2021
# 24      September 21, 2021
#                ...
# 8801         March 9, 2016
# 8802     November 20, 2019
# 8804      November 1, 2019
# 8805      January 11, 2020
# 8806         March 2, 2019
# Name: date_added, Length: 5332, dtype: str

# %%
df["date_added"] = pd.to_datetime(df["date_added"], format="mixed")
df["date_added"]
# Out:
# 7      2021-09-24
# 8      2021-09-24
# 9      2021-09-24
# 12     2021-09-23
# 24     2021-09-21
#           ...
# 8801   2016-03-09
# 8802   2019-11-20
# 8804   2019-11-01
# 8805   2020-01-11
# 8806   2019-03-02
# Name: date_added, Length: 5332, dtype: datetime64[us]

# %%
df["day_added"] = df["date_added"].dt.day
df["month_added"] = df["date_added"].dt.month
df["Year_added"] = df["date_added"].dt.year

# %%
df["type"].unique()
# Out:
# <StringArray>
# ['Movie', 'TV Show']
# Length: 2, dtype: str

# %%
plt.figure(figsize = (10,5))
sns.countplot(x = "type",data = netflix, hue = "type")
plt.title("Type")
plt.show()

# %%
df["rating"].unique()
# Out:
# <StringArray>
# [   'TV-MA',    'TV-14',    'PG-13',       'PG',        'R',    'TV-PG',
#         'G',    'TV-Y7',     'TV-G',     'TV-Y',    'NC-17',       'NR',
#  'TV-Y7-FV',       'UR']
# Length: 14, dtype: str

# %%
plt.figure(figsize=(12,6))
sns.countplot(x ="rating",data = netflix)
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.countplot(x="rating",hue = 'type', data = netflix)
plt.title("Relation Between Rating and Type")
# Out:
# Text(0.5, 1.0, 'Relation Between Rating and Type')

# %%
netflix['rating'].value_counts(ascending=False).head().plot.pie(autopct = "%.2f%%",
                                                                figsize = (16,9))
plt.show()
